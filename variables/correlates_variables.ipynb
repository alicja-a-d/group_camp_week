# %%
import pandas as pd

# %%
df = pd.read_csv('../Camp_Election.Oracle/Correlates of State Policy/correlates2-6.csv')
df = df[df['year'] > 1975]
df
# Out:
# C:\Users\jelle\AppData\Local\Temp\ipykernel_18664\306222963.py:1: DtypeWarning: Columns (487,491,497,499,502,504,508,511,518,523,525,530,1496,1871,2106,2269,2270,2271,2272,2273,2274,2275,2276) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('../Camp_Election.Oracle/Correlates of State Policy/correlates2-6.csv')
#       st  stateno    state  state_fips  state_icpsr  year  popdensity  \
# 76    AK      2.0   Alaska           2           81  1976    0.688202
# 77    AK      2.0   Alaska           2           81  1977    0.695225
# 78    AK      2.0   Alaska           2           81  1978    0.704003
# 79    AK      2.0   Alaska           2           81  1979    0.705759
# 80    AK      2.0   Alaska           2           81  1980    0.702247
# ...   ..      ...      ...         ...          ...   ...         ...
# 6166  WY     50.0  Wyoming          56           68  2016         NaN
# 6167  WY     50.0  Wyoming          56           68  2017         NaN
# 6168  WY     50.0  Wyoming          56           68  2018         NaN
# 6169  WY     50.0  Wyoming          56           68  2019         NaN
# 6170  WY     50.0  Wyoming          56           68  2020         NaN
#
#       popfemale  pctpopfemale  popmale  ...  num_enacted_laws  gunhomicides  \
# 76          NaN           NaN      NaN  ...               NaN           NaN
# 77          NaN           NaN      NaN  ...               NaN           NaN
# 78          NaN           NaN      NaN  ...               NaN           NaN
# 79          NaN           NaN      NaN  ...               NaN           NaN
# 80          NaN           NaN      NaN  ...               NaN           NaN
# ...         ...           ...      ...  ...               ...           ...
# 6166        NaN          49.1      NaN  ...               0.0           5.0
# 6167        NaN          48.9      NaN  ...               0.0           NaN
# 6168        NaN           NaN      NaN  ...               NaN           NaN
# 6169        NaN           NaN      NaN  ...               NaN           NaN
# 6170        NaN           NaN      NaN  ...               NaN           NaN
#
#       femmurdersfamilybygun  mass_shooting_num  numregdvgunlawenact  intropot  \
# 76                      NaN                NaN                  NaN       NaN
# 77                      NaN                NaN                  NaN       NaN
# 78                      NaN                NaN                  NaN       NaN
# 79                      NaN                NaN                  NaN       NaN
# 80                      NaN                NaN                  NaN       NaN
# ...                     ...                ...                  ...       ...
# 6166                    2.0                0.0                  2.0       1.0
# 6167                    NaN                0.0                  4.0       NaN
# 6168                    NaN                NaN                  NaN       NaN
# 6169                    NaN                NaN                  NaN       NaN
# 6170                    NaN                NaN                  NaN       NaN
#
#       signedpot  introcat1pot  introcat2pot  introcat3pot
# 76          NaN           NaN           NaN           NaN
# 77          NaN           NaN           NaN           NaN
# 78          NaN           NaN           NaN           NaN
# 79          NaN           NaN           NaN           NaN
# 80          NaN           NaN           NaN           NaN
# ...         ...           ...           ...           ...
# 6166        0.0           0.0           1.0           0.0
# 6167        NaN           NaN           NaN           NaN
# 6168        NaN           NaN           NaN           NaN
# 6169        NaN           NaN           NaN           NaN
# 6170        NaN           NaN           NaN           NaN
#
# [2295 rows x 3020 columns]

# %%
missing_percentage = df.isna().mean() * 100
#print(missing_percentage)
columns_to_keep = missing_percentage[missing_percentage <= 3].index
print(columns_to_keep)
df_filtered = df[columns_to_keep]
df_filtered
# Out:
# Index(['st', 'stateno', 'state', 'state_fips', 'state_icpsr', 'year',
#        'incomepcap', 'poptotal', 'taxes', 'legcount_sen_w', 'legcount_sen_b',
#        'legcount_sen_n', 'legcount_sen_e', 'legcount_sen_l', 'legcount_sen_ln',
#        'legcount_sen_el', 'legcount_sen_c', 'legcount_sen_bl',
#        'legcount_sen_s', 'legcount_sen_p', 'legcount_sen_ep',
#        'legcount_sen_elp', 'legcount_sen_bn', 'legcount_sen_m',
#        'legcount_sen_bs'],
#       dtype='object')
#       st  stateno    state  state_fips  state_icpsr  year  incomepcap  \
# 76    AK      2.0   Alaska           2           81  1976     12109.0
# 77    AK      2.0   Alaska           2           81  1977     12388.0
# 78    AK      2.0   Alaska           2           81  1978     12495.0
# 79    AK      2.0   Alaska           2           81  1979     13199.0
# 80    AK      2.0   Alaska           2           81  1980     14975.0
# ...   ..      ...      ...         ...          ...   ...         ...
# 6166  WY     50.0  Wyoming          56           68  2016     54073.0
# 6167  WY     50.0  Wyoming          56           68  2017     56421.0
# 6168  WY     50.0  Wyoming          56           68  2018     60537.0
# 6169  WY     50.0  Wyoming          56           68  2019     62044.0
# 6170  WY     50.0  Wyoming          56           68  2020         NaN
#
#       poptotal      taxes  legcount_sen_w  ...  legcount_sen_el  \
# 76    400969.0   598806.0            18.0  ...              0.0
# 77    403436.0   773474.0            18.0  ...              0.0
# 78    404766.0   563485.0            18.0  ...              0.0
# 79    402753.0   816710.0            18.0  ...              0.0
# 80    401851.0  1437607.0            18.0  ...              0.0
# ...        ...        ...             ...  ...              ...
# 6166  585501.0  1913607.0            29.0  ...              0.0
# 6167  579315.0  1649550.0            29.0  ...              0.0
# 6168  577601.0  1837401.0            29.0  ...              0.0
# 6169  578759.0  2110704.0            28.0  ...              0.0
# 6170       NaN        NaN            28.0  ...              0.0
#
#       legcount_sen_c  legcount_sen_bl  legcount_sen_s  legcount_sen_p  \
# 76               0.0              0.0             0.0             0.0
# 77               0.0              0.0             0.0             0.0
# 78               0.0              0.0             0.0             0.0
# 79               0.0              0.0             0.0             0.0
# 80               0.0              0.0             0.0             0.0
# ...              ...              ...             ...             ...
# 6166             0.0              0.0             0.0             0.0
# 6167             0.0              0.0             0.0             0.0
# 6168             0.0              0.0             0.0             0.0
# 6169             0.0              0.0             0.0             0.0
# 6170             0.0              0.0             0.0             0.0
#
#       legcount_sen_ep  legcount_sen_elp  legcount_sen_bn  legcount_sen_m  \
# 76                0.0               0.0              0.0             0.0
# 77                0.0               0.0              0.0             0.0
# 78                0.0               0.0              0.0             0.0
# 79                0.0               0.0              0.0             0.0
# 80                0.0               0.0              0.0             0.0
# ...               ...               ...              ...             ...
# 6166              0.0               0.0              0.0             0.0
# 6167              0.0               0.0              0.0             0.0
# 6168              0.0               0.0              0.0             0.0
# 6169              0.0               0.0              0.0             0.0
# 6170              0.0               0.0              0.0             0.0
#
#       legcount_sen_bs
# 76                0.0
# 77                0.0
# 78                0.0
# 79                0.0
# 80                0.0
# ...               ...
# 6166              0.0
# 6167              0.0
# 6168              0.0
# 6169              0.0
# 6170              0.0
#
# [2295 rows x 25 columns]
