# %%
import pandas as pd

# %%
df = pd.read_csv('../Camp_Election.Oracle/Historical Election Results/MIT_Lab_Historical_Election_Results/1976-2020-president.csv')
df
# Out:
#       year    state state_po  state_fips  state_cen  state_ic        office  \
# 0     1976  ALABAMA       AL           1         63        41  US PRESIDENT
# 1     1976  ALABAMA       AL           1         63        41  US PRESIDENT
# 2     1976  ALABAMA       AL           1         63        41  US PRESIDENT
# 3     1976  ALABAMA       AL           1         63        41  US PRESIDENT
# 4     1976  ALABAMA       AL           1         63        41  US PRESIDENT
# ...    ...      ...      ...         ...        ...       ...           ...
# 4282  2020  WYOMING       WY          56         83        68  US PRESIDENT
# 4283  2020  WYOMING       WY          56         83        68  US PRESIDENT
# 4284  2020  WYOMING       WY          56         83        68  US PRESIDENT
# 4285  2020  WYOMING       WY          56         83        68  US PRESIDENT
# 4286  2020  WYOMING       WY          56         83        68  US PRESIDENT
#
# ...

# %%
df = df[df['party_simplified'].str.contains('DEMOCRAT') | df['party_simplified'].str.contains('REPUBLICAN')]
df
# Out:
#       year          state state_po  state_fips  state_cen  state_ic  \
# 0     1976        ALABAMA       AL           1         63        41
# 1     1976        ALABAMA       AL           1         63        41
# 7     1976         ALASKA       AK           2         94        81
# 8     1976         ALASKA       AK           2         94        81
# 11    1976        ARIZONA       AZ           4         86        61
# ...    ...            ...      ...         ...        ...       ...
# 4264  2020  WEST VIRGINIA       WV          54         55        56
# 4267  2020      WISCONSIN       WI          55         35        25
# 4268  2020      WISCONSIN       WI          55         35        25
# 4280  2020        WYOMING       WY          56         83        68
# 4281  2020        WYOMING       WY          56         83        68
#
#             office            candidate party_detailed writein  \
# 0     US PRESIDENT        CARTER, JIMMY       DEMOCRAT   False
# ...

# %%
#result = df.groupby(['state', 'year'])[['candidatevotes', 'party_simplified']].max()
result = df.groupby(['state', 'year']).apply(lambda x: x.loc[x['candidatevotes'].idxmax()])[['party_simplified', 'candidatevotes']]
result = result.reset_index()
result
# Out:
#        state  year party_simplified  candidatevotes
# 0    ALABAMA  1976         DEMOCRAT          659170
# 1    ALABAMA  1980       REPUBLICAN          654192
# 2    ALABAMA  1984       REPUBLICAN          872849
# 3    ALABAMA  1988       REPUBLICAN          815576
# 4    ALABAMA  1992       REPUBLICAN          804283
# ..       ...   ...              ...             ...
# 607  WYOMING  2004       REPUBLICAN          167629
# 608  WYOMING  2008       REPUBLICAN          164958
# 609  WYOMING  2012       REPUBLICAN          170962
# 610  WYOMING  2016       REPUBLICAN          174419
# 611  WYOMING  2020       REPUBLICAN          193559
#
# [612 rows x 4 columns]

# %%
result[result['state'] == 'ARIZONA']
# Out:
#       state  year  candidatevotes party_simplified
# 24  ARIZONA  1976          418642       REPUBLICAN
# 25  ARIZONA  1980          529688       REPUBLICAN
# 26  ARIZONA  1984          681416       REPUBLICAN
# 27  ARIZONA  1988          702541       REPUBLICAN
# 28  ARIZONA  1992          572086       REPUBLICAN
# 29  ARIZONA  1996          653288       REPUBLICAN
# 30  ARIZONA  2000          781652       REPUBLICAN
# 31  ARIZONA  2004         1104294       REPUBLICAN
# 32  ARIZONA  2008         1230111       REPUBLICAN
# 33  ARIZONA  2012         1233654       REPUBLICAN
# 34  ARIZONA  2016         1252401       REPUBLICAN
# 35  ARIZONA  2020         1672143       REPUBLICAN

# %%
result.to_csv('previous_winners.csv')
