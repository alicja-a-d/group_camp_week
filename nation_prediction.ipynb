# %%
import pandas as pd

# %%
df = pd.read_csv('clean_TFC_data.csv')
results = pd.read_csv('Camp_Election.Oracle/Historical Election Results/MIT_Lab_Historical_Election_Results/1976-2020-president.csv')
results
# Out:
#       year    state state_po  state_fips  state_cen  state_ic        office  \
# 0     1976  ALABAMA       AL           1         63        41  US PRESIDENT
# 1     1976  ALABAMA       AL           1         63        41  US PRESIDENT
# 2     1976  ALABAMA       AL           1         63        41  US PRESIDENT
# 3     1976  ALABAMA       AL           1         63        41  US PRESIDENT
# 4     1976  ALABAMA       AL           1         63        41  US PRESIDENT
# ...    ...      ...      ...         ...        ...       ...           ...
# 4282  2020  WYOMING       WY          56         83        68  US PRESIDENT
# 4283  2020  WYOMING       WY          56         83        68  US PRESIDENT
# 4284  2020  WYOMING       WY          56         83        68  US PRESIDENT
# 4285  2020  WYOMING       WY          56         83        68  US PRESIDENT
# 4286  2020  WYOMING       WY          56         83        68  US PRESIDENT
#
# ...

# %%
# Focus on Democrats and Republicans only 
results = results[results['party_simplified'].str.contains('DEMOCRAT') | results['party_simplified'].str.contains('REPUBLICAN')]

# Calculate the two-party total votes for each state and year
results['two_party_total'] = results.groupby(['year', 'state'])['candidatevotes'].transform('sum')


results
# Out:
# C:\Users\jelle\AppData\Local\Temp\ipykernel_840\4229141691.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   results['two_party_total'] = results.groupby(['year', 'state'])['candidatevotes'].transform('sum')
#       year          state state_po  state_fips  state_cen  state_ic  \
# 0     1976        ALABAMA       AL           1         63        41
# 1     1976        ALABAMA       AL           1         63        41
# 7     1976         ALASKA       AK           2         94        81
# 8     1976         ALASKA       AK           2         94        81
# 11    1976        ARIZONA       AZ           4         86        61
# ...    ...            ...      ...         ...        ...       ...
# ...

# %%
results = results.drop_duplicates(subset=['state', 'year'])
df = pd.merge(df, results[['state', 'year', 'two_party_total']], on=['state', 'year'], how='left')
df
# Out:
#      year          state  pct_2p_vote  term2  real_gdp_pct_growth  \
# 0    1980        ALABAMA    49.323662      1                 -0.3
# 1    1980         ALASKA    32.700814      1                 -0.3
# 2    1980        ARIZONA    31.787913      1                 -0.3
# 3    1980       ARKANSAS    49.680294      1                 -0.3
# 4    1980     CALIFORNIA    40.533375      1                 -0.3
# ..    ...            ...          ...    ...                  ...
# 562  2020       VIRGINIA    44.845313      1                 -2.2
# 563  2020     WASHINGTON    40.074497      1                 -2.2
# 564  2020  WEST VIRGINIA    69.798532      1                 -2.2
# 565  2020      WISCONSIN    49.680937      1                 -2.2
# 566  2020        WYOMING    72.480434      1                 -2.2
#
#      net_approval  previous_winner_incumbent  two_party_total
# 0             -18                          1          1290922
# ...

# %%
weighted_avg = (df['pct_2p_vote'] * df['two_party_total']).groupby(df['year']).sum() / df.groupby('year')['two_party_total'].sum()
weighted_avg
# Out:
# year
# 1980    44.842441
# 1984    59.123351
# 1988    53.832455
# 1992    46.379304
# 1996    54.804024
# 2000    50.256673
# 2004    51.233012
# 2008    46.229233
# 2012    52.009893
# 2016    47.754982
# 2020    47.732013
# dtype: float64

# %%
df = df[['year', 'term2', 'real_gdp_pct_growth', 'net_approval']].drop_duplicates().reset_index(drop=True)
df['pct_vote'] = weighted_avg.tolist()
df
# Out:
#     year  term2  real_gdp_pct_growth  net_approval   pct_vote
# 0   1980      1                 -0.3           -18  44.842441
# 1   1984      1                  7.2            25  59.123351
# 2   1988      0                  4.2            13  53.832455
# 3   1992      0                  3.5           -22  46.379304
# 4   1996      1                  3.8            18  54.804024
# 5   2000      0                  4.1            19  50.256673
# 6   2004      1                  3.8             1  51.233012
# 7   2008      0                  0.1           -45  46.229233
# 8   2012      1                  2.3             7  52.009893
# 9   2016      0                  1.8            10  47.754982
# 10  2020      1                 -2.2            -6  47.732013

# %%
import statsmodels.api as sm

# Define your design matrix and your target variable 


# Specify the columns to be included in X. Ensure all are numeric
X = df[['term2', 'real_gdp_pct_growth', 'net_approval']]
y = df['pct_vote']

# Add a constant to the features to account for the intercept in the model
X_with_const = sm.add_constant(X)

# Fit the model
model = sm.OLS(y, X_with_const).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:               pct_vote   R-squared:                       0.818
# Model:                            OLS   Adj. R-squared:                  0.740
# Method:                 Least Squares   F-statistic:                     10.48
# Date:                Wed, 07 Feb 2024   Prob (F-statistic):            0.00556
# Time:                        16:03:02   Log-Likelihood:                -21.886
# No. Observations:                  11   AIC:                             51.77
# Df Residuals:                       7   BIC:                             53.36
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                           coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                  46.5524      1.524     30.545      0.000      42.949      50.156
# ...

# %%
Xtest = pd.DataFrame(columns = X.columns)
Xtest = X.iloc[:1].copy()
Xtest['term2'] = 1.0
Xtest['real_gdp_pct_growth'] = 2.5
Xtest['net_approval'] = -13
Xtest
test_prediction = model.predict(Xtest)
test_prediction
# Out:
# c:\Users\jelle\anaconda3\lib\site-packages\sklearn\utils\validation.py:767: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# c:\Users\jelle\anaconda3\lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# c:\Users\jelle\anaconda3\lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# array([50.47588954])

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X, y)
# Out:
# c:\Users\jelle\anaconda3\lib\site-packages\sklearn\utils\validation.py:767: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# c:\Users\jelle\anaconda3\lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# c:\Users\jelle\anaconda3\lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# ...

# %%
prediction = model.predict(Xtest)
prediction
# Out:
# c:\Users\jelle\anaconda3\lib\site-packages\sklearn\utils\validation.py:767: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if not hasattr(array, "sparse") and array.dtypes.apply(is_sparse).any():
# c:\Users\jelle\anaconda3\lib\site-packages\sklearn\utils\validation.py:605: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype):
# c:\Users\jelle\anaconda3\lib\site-packages\sklearn\utils\validation.py:614: FutureWarning: is_sparse is deprecated and will be removed in a future version. Check `isinstance(dtype, pd.SparseDtype)` instead.
#   if is_sparse(pd_dtype) or not is_extension_array_dtype(pd_dtype):
# array([50.47588954])
